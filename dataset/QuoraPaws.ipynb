# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/dataset'
# Out:
# /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/dataset

# %%
# !wget http://qim.fs.quoracdn.net/quora_duplicate_questions.tsv -P raw/quora
# Out:
# --2022-08-15 14:24:50--  http://qim.fs.quoracdn.net/quora_duplicate_questions.tsv
# Resolving qim.fs.quoracdn.net (qim.fs.quoracdn.net)... 151.101.1.2, 151.101.65.2, 151.101.129.2, ...
# Connecting to qim.fs.quoracdn.net (qim.fs.quoracdn.net)|151.101.1.2|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58176133 (55M) [text/tab-separated-values]
# Saving to: ‘raw/quora_duplicate_questions.tsv.1’
#
# quora_duplicate_que 100%[===================>]  55.48M  40.5MB/s    in 1.4s
#
# 2022-08-15 14:24:52 (40.5 MB/s) - ‘raw/quora_duplicate_questions.tsv.1’ saved [58176133/58176133]

# %%
# !pip install nltk==3.2.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nltk==3.2.5
#   Downloading nltk-3.2.5.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.2.5) (1.15.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.2.5-py3-none-any.whl size=1392156 sha256=0faf34577dd219f2a977bb83c5886b09236c929a8239ff27e62a3ad0a2a58c92
#   Stored in directory: /root/.cache/pip/wheels/60/de/57/6bced01d340818a36413222e6efcc7766d1f1e4575782b6223
# Successfully built nltk
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed nltk-3.2.5

# %%
# !python qqp_generate_data.py \
  --original_qqp_input="raw/quora/quora_duplicate_questions.tsv" \
  --paws_input="raw/quora/train.tsv" \
  --paws_output="raw/train_quora.tsv"

# !python qqp_generate_data.py \
  --original_qqp_input="raw/quora/quora_duplicate_questions.tsv" \
  --paws_input="raw/quora/dev_and_test.tsv" \
  --paws_output="raw/dev_and_test_quora.tsv"
# Out:
# Reading the original QQP corpus. This may take a while.
# Generating the PAWS-QQP corpus.
# ******Final Results********
#   Success: 11988
#   Fail:    0
#   Total:   11988
# Reading the original QQP corpus. This may take a while.
# Generating the PAWS-QQP corpus.
# ******Final Results********
#   Success: 677
#   Fail:    0
#   Total:   677

# %%
def para(row, anchor_col="sentence1", para_col="sentence2", label_col="label", path="paws", name="quora", split="train"):
  out_row = {
             "anchor": row[anchor_col][2:-1],
             "para": row[para_col][2:-1],
             "original_label": row[label_col],
             "path": path,
             "name": name,
             "split": split}
  return out_row

# %%
import pandas as pd

# %%
df = pd.read_csv("raw/train_quora.tsv", sep="\t")

df = df[df["label"] == 1]
out_list = []
for idx, row in df.iterrows():
    out_list.append(para(row, split="train"))

pd.DataFrame(out_list).to_csv("raw/out_paws_quora_train.csv")

# %%
df = pd.read_csv("raw/dev_and_test_quora.tsv", sep="\t")

df = df[df["label"] == 1]
out_list = []
for idx, row in df.iterrows():
    out_list.append(para(row, split="test"))

pd.DataFrame(out_list).to_csv("raw/out_paws_quora_test.csv")
