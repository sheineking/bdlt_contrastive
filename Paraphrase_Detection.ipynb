# %% [markdown]
# # 1. Preparation

# %% [markdown]
# ## 1.1 Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.2 Get correct CuDNN version
# See https://github.com/googlecolab/colabtools/issues/2600

# %%
# !apt install --allow-change-held-packages libcudnn8=8.4.1.50-1+cuda11.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 18 not upgraded.
# Need to get 420 MB of archives.
# After this operation, 3,369 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.4.1.50-1+cuda11.6 [420 MB]
# Fetched 420 MB in 7s (62.0 MB/s)
# (Reading database ... 155676 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155654 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.4.1.50-1+cuda11.6_amd64.deb ...
# Unpacking libcudnn8 (8.4.1.50-1+cuda11.6) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.4.1.50-1+cuda11.6) ...

# %% [markdown]
# ## 1.3 Install necessary packages

# %%
# %cd '/content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive'
# Out:
# /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive

# %%
# !python3 -m pip install -r 'requirements.txt'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting transformers==4.20.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 4.2 MB/s
# Collecting datasets==2.3.2
#   Downloading datasets-2.3.2-py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 57.6 MB/s
# Collecting wandb==0.12.16
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 54.1 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (0.13.1+cu113)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.12.1+cu113)
# Collecting info-nce-pytorch==0.1.4
#   Downloading info_nce_pytorch-0.1.4-py3-none-any.whl (4.8 kB)
# Collecting torchlars==0.1.2
#   Downloading torchlars-0.1.2.tar.gz (6.5 kB)
# Collecting torchmetrics==0.9.3
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 61.3 MB/s
# Collecting protobuf==3.20.0
#   Downloading protobuf-3.20.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 60.6 MB/s
# Requirement already satisfied: tensorboard==2.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 16)) (2.8.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.4 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.20.1->-r requirements.txt (line 1)) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 53.2 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 56.7 MB/s
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 76.4 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 73.6 MB/s
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets==2.3.2->-r requirements.txt (line 2)) (0.3.5.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 75.3 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets==2.3.2->-r requirements.txt (line 2)) (3.8.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==2.3.2->-r requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==2.3.2->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (2.8.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 57.1 MB/s
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb==0.12.16->-r requirements.txt (line 3)) (57.4.0)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 61.7 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics==0.9.3->-r requirements.txt (line 13)) (4.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.8.0->-r requirements.txt (line 16)) (1.47.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.9 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0->-r requirements.txt (line 16)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0->-r requirements.txt (line 16)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.8.0->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.20.1->-r requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.20.1->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.8.0->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.20.1->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.20.1->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.20.1->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.20.1->-r requirements.txt (line 1)) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.8.0->-r requirements.txt (line 16)) (3.2.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 71.8 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 80.3 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 73.1 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 79.0 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 22.3 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 67.4 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->-r requirements.txt (line 8)) (7.1.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets==2.3.2->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==2.3.2->-r requirements.txt (line 2)) (2022.1)
# Building wheels for collected packages: torchlars, pathtools
#   Building wheel for torchlars (setup.py) ... done
#   Created wheel for torchlars: filename=torchlars-0.1.2-cp37-cp37m-linux_x86_64.whl size=1188176 sha256=c64c790892d65883ab6da03d0dd76e9a7c9e0f4f5f54363293106fc651ee4034
#   Stored in directory: /root/.cache/pip/wheels/ae/a9/96/62995a5abfd27e2f46671e17b99a52b6dccf46391d2b0e1c17
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=f0a8d9c3b1996534dafae474765abf9cabc0a43233854faf64316c74af46262a
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built torchlars pathtools
# Installing collected packages: urllib3, smmap, pyyaml, gitdb, fsspec, xxhash, tokenizers, shortuuid, setproctitle, sentry-sdk, responses, protobuf, pathtools, multiprocess, huggingface-hub, GitPython, docker-pycreds, wandb, transformers, torchmetrics, torchlars, info-nce-pytorch, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed GitPython-3.1.27 datasets-2.3.2 docker-pycreds-0.4.0 fsspec-2022.7.1 gitdb-4.0.9 huggingface-hub-0.8.1 info-nce-pytorch-0.1.4 multiprocess-0.70.13 pathtools-0.1.2 protobuf-3.20.0 pyyaml-6.0 responses-0.18.0 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 tokenizers-0.12.1 torchlars-0.1.2 torchmetrics-0.9.3 transformers-4.20.1 urllib3-1.25.11 wandb-0.12.16 xxhash-3.0.0

# %% [markdown]
# # 2. Training
# Use the main.py script with the two mandatory flags: mode and config.
# Other flags can be provided to change individual parameter.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# Ensure that the correct folder is active
# %cd '/content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive'
# !python3 main.py --mode=contrastive --epochs 3
# Out:
# /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive
# No config-flag was provided. Looping over all available configurations for mode=contrastive
#
#
#
# ==================================================
#        Contrastive Learning
# ==================================================
# Preparing the tokenizer...
# Preparing the model...
# Initial preparation completed.
# - Model weights will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_SGD.pt
# - Tensorboard logs will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/tensorboard_logs/Pairwise_SGD/
# - CSV logs will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/csv_logs/Pairwise_SGD.csv
#
#
# Using custom data configuration JoPro--contrastive_paraphrases-797bd93366b8de28
# Downloading and preparing dataset csv/contrastive_paws_parabank (download: 35.31 MiB, generated: 67.26 MiB, post-processed: Unknown size, total: 102.57 MiB) to /root/.cache/huggingface/datasets/JoPro___parquet/JoPro--contrastive_paraphrases-797bd93366b8de28/0.0.0/7328ef7ee03eaf3f86ae40594d46a1cec86161704e02dd19f232d81eee72ade8...
# Downloading data files: 100% 3/3 [00:00<00:00, 5102.56it/s]
# Extracting data files: 100% 3/3 [00:00<00:00, 1375.33it/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/JoPro___parquet/JoPro--contrastive_paraphrases-797bd93366b8de28/0.0.0/7328ef7ee03eaf3f86ae40594d46a1cec86161704e02dd19f232d81eee72ade8. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 434.76it/s]
# Parameter 'function'=<function LearningManager.load_dataset.<locals>.<lambda> at 0x7fec1f55b320> of the transform datasets.arrow_dataset.Dataset.filter@2.0.1 couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 100% 77/77 [00:00<00:00, 177.86ba/s]
# 100% 12/12 [00:00<00:00, 172.06ba/s]
# 100% 4/4 [00:00<00:00, 188.54ba/s]
# 100% 77/77 [00:00<00:00, 87.97ba/s]
# 100% 12/12 [00:00<00:00, 85.73ba/s]
# 100% 4/4 [00:00<00:00, 96.94ba/s]
# 100% 76862/76862 [01:11<00:00, 1080.81ex/s]
# 100% 11765/11765 [00:10<00:00, 1118.26ex/s]
# 100% 3676/3676 [00:03<00:00, 1167.47ex/s]
#
# Performing training based on the following parameters:
# - Epochs:           3
# - Batchsize:        16
# - Num sentences:    2
# - Optimizer:        SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     lr: 0.1
#     maximize: False
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# - Loss:             PairwiseLoss(
#   (pdist): PairwiseDistance()
# )
# - Patience:         3
#
#
#
# ----------------------------------------------------------------------------------------------------
# Epoch 1/3
# train_loss = 0.00024544 |
# val_loss   = 0.00000569 |
# New checkpoint for validation loss. Model weights saved to /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_SGD.pt
#
#
# ----------------------------------------------------------------------------------------------------
# Epoch 2/3
# train_loss = 0.00007519 |
# val_loss   = 0.00000300 |
# New checkpoint for validation loss. Model weights saved to /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_SGD.pt
#
#
# ----------------------------------------------------------------------------------------------------
# Epoch 3/3
# train_loss = 0.00002009 |
# val_loss   = 0.00000109 |
# New checkpoint for validation loss. Model weights saved to /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_SGD.pt
#
#
# ==================================================
#        Contrastive Learning
# ==================================================
# Preparing the tokenizer...
# Preparing the model...
# Initial preparation completed.
# - Model weights will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_RMS.pt
# - Tensorboard logs will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/tensorboard_logs/Pairwise_RMS/
# - CSV logs will be saved to: /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/csv_logs/Pairwise_RMS.csv
#
#
# Using custom data configuration JoPro--contrastive_paraphrases-797bd93366b8de28
# Reusing dataset parquet (/root/.cache/huggingface/datasets/JoPro___parquet/JoPro--contrastive_paraphrases-797bd93366b8de28/0.0.0/7328ef7ee03eaf3f86ae40594d46a1cec86161704e02dd19f232d81eee72ade8)
# 100% 3/3 [00:00<00:00, 727.97it/s]
# 100% 77/77 [00:00<00:00, 154.53ba/s]
# 100% 12/12 [00:00<00:00, 139.57ba/s]
# 100% 4/4 [00:00<00:00, 170.78ba/s]
# 100% 77/77 [00:00<00:00, 85.03ba/s]
# 100% 12/12 [00:00<00:00, 93.35ba/s]
# 100% 4/4 [00:00<00:00, 89.44ba/s]
# 100% 76862/76862 [01:16<00:00, 1002.83ex/s]
# 100% 11765/11765 [00:11<00:00, 1026.70ex/s]
# 100% 3676/3676 [00:03<00:00, 1054.18ex/s]
#
# Performing training based on the following parameters:
# - Epochs:           3
# - Batchsize:        16
# - Num sentences:    2
# - Optimizer:        RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.1
#     momentum: 0
#     weight_decay: 0
# )
# - Loss:             PairwiseLoss(
#   (pdist): PairwiseDistance()
# )
# - Patience:         3
#
#
#
# ----------------------------------------------------------------------------------------------------
# Epoch 1/3
# train_loss = 0.00000589 |
# val_loss   = 0.00000000 |
# New checkpoint for validation loss. Model weights saved to /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive/contrastive/models/weights/Pairwise_RMS.pt
#
#
# ----------------------------------------------------------------------------------------------------
# Epoch 2/3

# %% [markdown]
# #3 Hyper Parameter Sweeping with wandb

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# Aborted!
# ^C

# %%
# Ensure that the correct folder is active
# %cd '/content/drive/MyDrive/BDLT_Contrastive/sweeping'
# !python3 sweeping.py --mode=supervised
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/BDLT_Contrastive/sweeping'
# /content/drive/MyDrive/Uni Leipzig/SS2022/bdlt_contrastive
# python3: can't open file 'sweeping.py': [Errno 2] No such file or directory
